# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
 
from sklearn import datasets 
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import accuracy_score,confusion_matrix

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
company_data = pd.read_csv('Company_Data.csv')
company_data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
company_data.loc[company_data['Sales']>=7,'sales'] = 'High'
company_data.loc[company_data['Sales']<7,'sales'] = 'Low'

# %%
company_data.drop('Sales',axis = 1, inplace=True)

# %%
company_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CompPrice    400 non-null    int64
#  1   Income       400 non-null    int64
#  2   Advertising  400 non-null    int64
#  3   Population   400 non-null    int64
#  4   Price        400 non-null    int64
#  5   ShelveLoc    400 non-null    object
#  6   Age          400 non-null    int64
#  7   Education    400 non-null    int64
#  8   Urban        400 non-null    object
#  9   US           400 non-null    object
#  10  sales        400 non-null    object
# dtypes: int64(7), object(4)
# memory usage: 34.5+ KB

# %%
company_data.describe(include='all')
# Out:
#          CompPrice      Income  Advertising  Population       Price ShelveLoc  \
# count   400.000000  400.000000   400.000000  400.000000  400.000000       400
# unique         NaN         NaN          NaN         NaN         NaN         3
# top            NaN         NaN          NaN         NaN         NaN    Medium
# freq           NaN         NaN          NaN         NaN         NaN       219
# mean    124.975000   68.657500     6.635000  264.840000  115.795000       NaN
# std      15.334512   27.986037     6.650364  147.376436   23.676664       NaN
# min      77.000000   21.000000     0.000000   10.000000   24.000000       NaN
# 25%     115.000000   42.750000     0.000000  139.000000  100.000000       NaN
# 50%     125.000000   69.000000     5.000000  272.000000  117.000000       NaN
# 75%     135.000000   91.000000    12.000000  398.500000  131.000000       NaN
# max     175.000000  120.000000    29.000000  509.000000  191.000000       NaN
#
#                Age   Education Urban   US sales
# count   400.000000  400.000000   400  400   400
# unique         NaN         NaN     2    2     2
# top            NaN         NaN   Yes  Yes  High
# freq           NaN         NaN   282  258   216
# mean     53.322500   13.900000   NaN  NaN   NaN
# std      16.200297    2.620528   NaN  NaN   NaN
# min      25.000000   10.000000   NaN  NaN   NaN
# 25%      39.750000   12.000000   NaN  NaN   NaN
# 50%      54.500000   14.000000   NaN  NaN   NaN
# 75%      66.000000   16.000000   NaN  NaN   NaN
# max      80.000000   18.000000   NaN  NaN   NaN

# %%
company_data.dtypes
# Out:
# CompPrice       int64
# Income          int64
# Advertising     int64
# Population      int64
# Price           int64
# ShelveLoc      object
# Age             int64
# Education       int64
# Urban          object
# US             object
# sales          object
# dtype: object

# %%
label_encoder = preprocessing.LabelEncoder()
company_data['ShelveLoc']= label_encoder.fit_transform(company_data['ShelveLoc'])

# %%
company_data['Urban']= label_encoder.fit_transform(company_data['Urban'])

# %%
company_data['US']= label_encoder.fit_transform(company_data['US'])

# %%
company_data.head()
# Out:
#    CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0        138      73           11         276    120          0   42
# 1        111      48           16         260     83          1   65
# 2        113      35           10         269     80          2   59
# 3        117     100            4         466     97          2   55
# 4        141      64            3         340    128          0   38
#
#    Education  Urban  US sales
# 0         17      1   1  High
# 1         10      1   1  High
# 2         12      1   1  High
# 3         14      1   1  High
# 4         13      1   0   Low

# %%
X = company_data.iloc[:,:10]
Y = company_data[['sales']]

# %%
Y
# Out:
#     sales
# 0    High
# 1    High
# 2    High
# 3    High
# 4     Low
# ..    ...
# 395  High
# 396   Low
# 397  High
# 398   Low
# 399  High
#
# [400 rows x 1 columns]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.20,random_state=10)

# %%
X_train.shape,Y_train.shape
# Out:
# ((320, 10), (320, 1))

# %%
X_test.shape,Y_test.shape
# Out:
# ((80, 10), (80, 1))

# %%
X_train
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 303        133      52           16         290     99          2   43
# 349        134      27           18         467     96          2   49
# 149        121     120           13         140     87          2   56
# 100        113      69           11          94    106          2   76
# 175        115      89            0          38    122          2   25
# ..         ...     ...          ...         ...    ...        ...  ...
# 369        135     100           22         463    122          2   36
# 320        136      70           12         171    152          2   44
# 15         149      95            5         400    144          2   76
# 125         89      78            0         181     49          2   43
# 265        130      35           10         402    129          0   39
#
#      Education  Urban  US
# 303         11      1   1
# 349         14      0   1
# 149         11      1   1
# 100         12      0   1
# 175         12      1   0
# ..         ...    ...  ..
# 369         14      1   1
# 320         18      1   1
# 15          18      0   0
# 125         15      0   0
# 265         17      1   1
#
# [320 rows x 10 columns]

# %%
model = DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_train_pred = model.predict(X_train)

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (8,6), dpi=300)
tree.plot_tree(model,filled=True);

# %%
print('Accuracy score:',accuracy_score(Y_train,Y_train_pred))
# Out:
# Accuracy score: 1.0

# %%
print('Confusion Matrix:\n ',confusion_matrix(Y_train,Y_train_pred))
# Out:
# Confusion Matrix:
#   [[177   0]
#  [  0 143]]

# %%
Y_test_pred = model.predict(X_test)

# %%
print('Accuracy score:', accuracy_score(Y_test,Y_test_pred))
# Out:
# Accuracy score: 0.75

# %%
print('Confusion Matrix \n', confusion_matrix(Y_test,Y_test_pred))
# Out:
# Confusion Matrix
#  [[31  8]
#  [12 29]]

# %% [markdown]
# ### High training accuracy and low testing accuracy indicates that the model is overfitting.

# %%
#Applying ensemple technique to overcome overfitting
gbc = GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
Y_train_pred_gbc = gbc.predict(X_train)
print('Accuracy score:',accuracy_score(Y_train,Y_train_pred_gbc))
# Out:
# Accuracy score: 0.996875

# %%
print('Confusion Matrix\n', confusion_matrix(Y_train,Y_train_pred_gbc))
# Out:
# Confusion Matrix
#  [[176   1]
#  [  0 143]]

# %%
Y_test_pred_gbc = gbc.predict(X_test)

# %%
print('Accuracy score:',accuracy_score(Y_test,Y_test_pred_gbc))
# Out:
# Accuracy score: 0.8125

# %%
print('Confusion Matrix :\n', confusion_matrix(Y_test,Y_test_pred_gbc))
# Out:
# Confusion Matrix :
#  [[32  7]
#  [ 8 33]]

# %%
abc = AdaBoostClassifier()
abc.fit(X_train,Y_train)
# Out:
# AdaBoostClassifier()

# %%
Y_train_pred_abc = abc.predict(X_train)
print('Accuracy score:', accuracy_score(Y_train,Y_train_pred_abc))
# Out:
# Accuracy score: 0.953125

# %%
print('COnfusion Matrix :\n', confusion_matrix(Y_train,Y_train_pred_abc))
# Out:
# COnfusion Matrix :
#  [[169   8]
#  [  7 136]]

# %%
Y_test_pred_abc = abc.predict(X_test)
print('Accuracy score:', accuracy_score(Y_test,Y_test_pred_abc))
# Out:
# Accuracy score: 0.825

# %%
print('COnfusion Matrix :\n', confusion_matrix(Y_test,Y_test_pred_abc))
# Out:
# COnfusion Matrix :
#  [[33  6]
#  [ 8 33]]

# %% [markdown]
# ### Adaboost showing the best accuracy than that of Gradient boosting
